# %%
# %pip install 'autogen-agentchat==0.4.0.dev11'
# %pip install 'autogen-ext[openai]==0.4.0.dev11'
# Out:
# Requirement already satisfied: autogen-agentchat==0.4.0.dev11 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (0.4.0.dev11)
# Requirement already satisfied: autogen-core==0.4.0.dev11 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-agentchat==0.4.0.dev11) (0.4.0.dev11)
# Requirement already satisfied: aioconsole in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.8.1)
# Requirement already satisfied: aiohttp in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (3.11.10)
# Requirement already satisfied: asyncio-atexit in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.0.1)
# Requirement already satisfied: jsonref~=1.1.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.1.0)
# Requirement already satisfied: openai>=1.3 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.57.4)
# Requirement already satisfied: opentelemetry-api~=1.27.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.27.0)
# Requirement already satisfied: pillow in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (11.0.0)
# Requirement already satisfied: protobuf~=4.25.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (4.25.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2.10.3)
# Requirement already satisfied: tiktoken in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.8.0)
# Requirement already satisfied: typing-extensions in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.8.2)
# Requirement already satisfied: sniffio in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (4.67.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (8.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2.27.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.18.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from tiktoken->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from tiktoken->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (3.10)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.17.0)
# Requirement already satisfied: certifi in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->autogen-core==0.4.0.dev11->autogen-agentchat==0.4.0.dev11) (2.2.3)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: autogen-ext==0.4.0.dev11 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-ext[openai]==0.4.0.dev11) (0.4.0.dev11)
# Requirement already satisfied: autogen-core==0.4.0.dev11 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (0.4.0.dev11)
# Requirement already satisfied: aiofiles in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-ext[openai]==0.4.0.dev11) (24.1.0)
# Requirement already satisfied: openai>=1.3 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-ext[openai]==0.4.0.dev11) (1.57.4)
# Requirement already satisfied: aioconsole in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (0.8.1)
# Requirement already satisfied: aiohttp in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (3.11.10)
# Requirement already satisfied: asyncio-atexit in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.0.1)
# Requirement already satisfied: jsonref~=1.1.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.1.0)
# Requirement already satisfied: opentelemetry-api~=1.27.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.27.0)
# Requirement already satisfied: pillow in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (11.0.0)
# Requirement already satisfied: protobuf~=4.25.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (4.25.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (2.10.3)
# Requirement already satisfied: tiktoken in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (0.8.0)
# Requirement already satisfied: typing-extensions in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (0.8.2)
# Requirement already satisfied: sniffio in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (3.10)
# Requirement already satisfied: certifi in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3->autogen-ext[openai]==0.4.0.dev11) (0.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (8.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (2.27.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from aiohttp->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.18.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from tiktoken->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from tiktoken->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (2.32.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (1.17.0)
# Requirement already satisfied: zipp>=0.5 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kiendoit/workspaces/ai-lab/autogen/myautogen/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->autogen-core==0.4.0.dev11->autogen-ext==0.4.0.dev11->autogen-ext[openai]==0.4.0.dev11) (2.2.3)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# from autogen import ConversableAgent
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.messages import TextMessage
from autogen_core import CancellationToken

os.environ['OPENAI_API_KEY'] = ''

# Create an agent that uses the OpenAI GPT-4o model.
model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key="",
)

#####################
# Define the agents #
# - Use the springdoc-openapi-starter-webmvc-ui to generate OpenAPI specification - FAIL
#####################

engineer = AssistantAgent(
    name="Engineer",
    model_client=model_client,
    system_message="""
    I am a seasoned Software Engineer, responsible for writing clean, efficient, and maintainable code based on the tasks assigned by the Project Manager. 
    My focus is exclusively on coding and ensuring that the code meets the specified requirements.

    Key Responsibilities:
    - Implement features and fixes according to the provided task specifications.
    - Write code that adheres to best practices and is optimized for performance and readability.
    - Ensure the solution compile successfully
    - Use the latest Spring Boot 3 library for the project
    - Ensure the code has minimum 80% test coverage
    - Use lombok library to simplify the data layer code
    - Use the Spring Actuator library to expose a health check endpoint
    - Ensure that the code is well-documented to facilitate future maintenance and collaboration.
    - Tools available to use include Java 17, maven, Spring Boot 3 and Spring Boot CLI

    Restrictions:
    - I NEVER manage or assign tasks.
    - I do not make decisions regarding the project scope or task prioritization.

    My goal is to deliver high-quality code that meets the requirements set forth by the Project Manager and the Admin.
    """,
)

project_manager = AssistantAgent(
    name="Project_Manager",
    model_client=model_client,
    system_message="""
    I am an experienced Project Manager overseeing the development of a software product. My responsibilities include translating the requirements provided by the Admin into manageable tasks, which I then assign to the Engineer.

    Key Responsibilities:
    - Break down project requirements into detailed, manageable tasks.
    - Assign tasks to the Engineer in a logical and efficient sequence.
    - Monitor the progress of the project and ensure timely delivery of each task.

    Workflow:
    - For each completed task, I will assess if further tasks are required.
    - I will ensure that any identified issues are resolved before moving on to the next task.
    - When the project is complete, I will confirm the project's completion with a "DONE" message.

    Restrictions:
    - I never suggest, review, or test code; my focus is purely on task management and project oversight.
    - I do not get involved in the technical implementation details.

    My goal is to ensure the smooth progression of the project from start to finish, maintaining clear communication and efficient task management.
    """,
)

async def user_proxy_run() -> None:
    user_proxy_agent = UserProxyAgent("user_proxy")
    response = await user_proxy_agent.on_messages(
        [TextMessage(content="What is your name? ", source="user")], cancellation_token=CancellationToken()
    )
    print(f"Your name is {response.chat_message.content}")


# Use asyncio.run(user_proxy_run()) when running in a script.
await user_proxy_run()

# user_proxy = UserProxyAgent(
#     name="Admin",
#     human_input_mode="ALWAYS",
#     code_execution_config=False,
# )

# %%
groupchat = autogen.GroupChat(
    agents=[user_proxy, project_manager, engineer],
    messages=[],
    max_round=100,
    send_introductions=True,
    enable_clear_history=True,
)
manager = autogen.GroupChatManager(
    groupchat=groupchat, 
    llm_config=llm_config, 
    is_termination_msg=lambda msg: "done" in msg["content"].lower()
)

####################
# Tool definitions #
####################
default_path = os.path.abspath("./output") + "/"

@user_proxy.register_for_execution()
@engineer.register_for_llm(description="List files in chosen directory.")
def list_dir(
    directory: Annotated[str, "Directory to check."]
) -> Annotated[Tuple[int, List[str]], "Status code and list of files"]:
    files = os.listdir(default_path + directory)
    return 0, files

@user_proxy.register_for_execution()
@engineer.register_for_llm(description="Check the contents of a chosen file.")
def see_file(
    filename: Annotated[str, "Name and path of file to check."]
) -> Annotated[Tuple[int, str], "Status code and file contents."]:
    with open(default_path + filename, "r") as file:
        lines = file.readlines()
    formatted_lines = [f"{i+1}:{line}" for i, line in enumerate(lines)]
    file_contents = "".join(formatted_lines)

    return 0, file_contents

@user_proxy.register_for_execution()
@engineer.register_for_llm(description="Replaces all the code within a file with new one. Proper indentation is important.")
def modify_code(
    filename: Annotated[str, "Name and path of file to change."],
    new_code: Annotated[str, "New piece of code to replace old code with. Remember about providing indents."],
) -> Annotated[Tuple[int, str], "Status code and message."]:
    with open(default_path + filename, "w") as file:
        file.write(new_code)
    return 0, "Code was written successfully."


@user_proxy.register_for_execution()
@engineer.register_for_llm(description="Create a new file with code.")
def create_file_with_code(
    filename: Annotated[str, "Name and path of file to create."], 
    code: Annotated[str, "Code to write in the file."]
) -> Annotated[Tuple[int, str], "Status code and message."]:
    with open(default_path + filename, "w") as file:
        file.write(code)
    return 0, "File created successfully"

@user_proxy.register_for_execution()
@engineer.register_for_llm(description="Execute bash command.")
def execute_command(
    command: Annotated[str, "Command to execute."]
) -> Annotated[Tuple[int, str], "Status code and message."]:
    os.system(f"CI=true cd {default_path} && {command}")
    return 0, "Command executed successfully"

##################
# Start the chat #
##################
chat_result = user_proxy.initiate_chat(
    manager,
    message="""
Create a Spring Boot microservice that exposes a REST API for managing a list of books. The service should support the following operations:
- Add a new book
- Update an existing book
- Delete a book by ID
- Retrieve a book by ID
- Retrieve all books
- Health check endpoint
The service should use the latest version of Spring Boot and should be well-structured, following best practices for RESTful APIs. 
Ensure that the code is clean, well-documented, and includes appropriate error handling.
All the java code should be under package com.metlife.bookstore.
""",
)

# print the token usage
#print(chat_result["token_usage"])
